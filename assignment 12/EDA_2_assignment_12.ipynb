# %%
Roll no:108806
Name: Rohith R
course name:DA
batch:geetika mam batch (9:30 to 11:30)

# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data exploration and preprocessing

# %%
# load the dataset 
df=pd.read_csv('adult_with_headers.csv')
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
# To Know the shape of the dataset
df.shape
# Out:
# (32561, 15)

# %%
# To get info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# To identify null values in the dataset
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# To identify the duplicated values in dataset
df.duplicated().sum()
# Out:
# 24

# %%
# TO know how many duplicated values are there in dataset
duplicated_rows=df[df.duplicated()]
duplicated_rows
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# 22367   44            Private  367749      Bachelors             13
# 22494   49   Self-emp-not-inc   43479   Some-college             10
# 25872   23            Private  240137        5th-6th              3
# 26313   28            Private  274679        Masters             14
# 28230   27            Private  255582        HS-grad              9
# 28522   42            Private  204235   Some-college             10
# 28846   39            Private   30916        HS-grad              9
# 29157   38            Private  207202        HS-grad              9
# 30845   46            Private  133616   Some-college             10
# 31993   19            Private  251579   Some-college             10
# 32404   35            Private  379959        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 4881         Never-married        Craft-repair   Not-in-family
# 5104         Never-married       Other-service   Not-in-family
# 9171         Never-married      Prof-specialty       Own-child
# 11631        Never-married        Tech-support   Not-in-family
# 13084        Never-married     Priv-house-serv   Not-in-family
# 15059        Never-married     Farming-fishing   Not-in-family
# 17040   Married-civ-spouse        Craft-repair         Husband
# 18555        Never-married       Other-service   Not-in-family
# 18698        Never-married     Farming-fishing   Not-in-family
# 21318        Never-married        Adm-clerical       Own-child
# 21490        Never-married     Exec-managerial       Own-child
# 21875   Married-civ-spouse        Craft-repair         Husband
# 22300        Never-married     Priv-house-serv   Not-in-family
# 22367        Never-married      Prof-specialty   Not-in-family
# 22494   Married-civ-spouse        Craft-repair         Husband
# 25872        Never-married   Handlers-cleaners   Not-in-family
# 26313        Never-married      Prof-specialty   Not-in-family
# 28230        Never-married   Machine-op-inspct   Not-in-family
# 28522   Married-civ-spouse      Prof-specialty         Husband
# 28846   Married-civ-spouse        Craft-repair         Husband
# 29157   Married-civ-spouse   Machine-op-inspct         Husband
# 30845             Divorced        Adm-clerical       Unmarried
# 31993        Never-married       Other-service       Own-child
# 32404             Divorced       Other-service   Not-in-family
#
#                       race      sex  capital_gain  capital_loss  \
# 4881                 White     Male             0             0
# 5104    Asian-Pac-Islander     Male             0             0
# 9171                 White   Female             0             0
# 11631                White   Female             0             0
# 13084                White   Female             0             0
# 15059                White     Male             0             0
# 17040                White     Male             0             0
# 18555                Black     Male             0             0
# 18698                White     Male             0             0
# 21318                White   Female             0             0
# 21490                Black     Male             0             0
# 21875                White     Male             0             0
# 22300                White   Female             0             0
# 22367                White   Female             0             0
# 22494                White     Male             0             0
# 25872                White     Male             0             0
# 26313                White     Male             0             0
# 28230                White   Female             0             0
# 28522                White     Male             0             0
# 28846                White     Male             0             0
# 29157                White     Male             0             0
# 30845                White   Female             0             0
# 31993                White     Male             0             0
# 32404                White   Female             0             0
#
#        hours_per_week  native_country  income
# 4881               40          Mexico   <=50K
# 5104               35   United-States   <=50K
# 9171               10   United-States   <=50K
# 11631              10   United-States   <=50K
# 13084              40       Guatemala   <=50K
# 15059              50          Mexico   <=50K
# 17040              40   United-States   <=50K
# 18555              40               ?   <=50K
# 18698              40   United-States   <=50K
# 21318              10   United-States   <=50K
# 21490              30   United-States   <=50K
# 21875              40   United-States   <=50K
# 22300              40       Guatemala   <=50K
# 22367              45          Mexico   <=50K
# 22494              40   United-States   <=50K
# 25872              55          Mexico   <=50K
# 26313              50   United-States   <=50K
# 28230              40   United-States   <=50K
# 28522              40   United-States    >50K
# 28846              40   United-States   <=50K
# 29157              48   United-States    >50K
# 30845              40   United-States   <=50K
# 31993              14   United-States   <=50K
# 32404              40   United-States   <=50K

# %%
# To remove duplicates in the dataset
df=df.drop_duplicates()
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32537 rows x 15 columns]

# %%
# the describe the dataset
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32537.000000  3.253700e+04   32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### visualization

# %%
import math
# To check the distribution and presence of outliers in the dataset using histogram and boxplots 
# Histogram
num_cols=len(df.columns)
n_cols=3 # for wider columns increase the number
n_rows=math.ceil(num_cols/n_cols)
plt.figure(figsize=(5 * n_cols, 5 * n_rows))
for i, col in enumerate(df.columns):
    plt.subplot(n_rows,n_cols,i+1)
    sns.histplot(df[col],kde=True)
    plt.title(f'The histogram of {col}')
    plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# %%
# boxplots
## To dynamically adjust the plot size
num_cols=len(df.columns)
n_cols=3
n_rows=math.ceil(num_cols/n_cols)
plt.figure(figsize=(15,15))
for i,col in enumerate(df.columns):
    plt.subplot(n_rows,n_cols,i+1)
    sns.boxplot(y=df[col],linecolor='red',linewidth=1.5)
    plt.title(f'The boxplot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# - As we see from th above boxplots presence of outliers in data is clearly visible which has to be treated properly

# %%
# To standardize the numerical columns in dataset
from sklearn.preprocessing import StandardScaler
s_scaler=StandardScaler()
numeric_s=df.select_dtypes(include=np.number).columns
df[numeric_s]=s_scaler.fit_transform(df[numeric_s])
df
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.030390          State-gov -1.063569    Bachelors       1.134777
# 1      0.836973   Self-emp-not-inc -1.008668    Bachelors       1.134777
# 2     -0.042936            Private  0.245040      HS-grad      -0.420679
# 3      1.056950            Private  0.425752         11th      -1.198407
# 4     -0.776193            Private  1.408066    Bachelors       1.134777
# ...         ...                ...       ...          ...            ...
# 32556 -0.849519            Private  0.639678   Assoc-acdm       0.745913
# 32557  0.103716            Private -0.335436      HS-grad      -0.420679
# 32558  1.423579            Private -0.358779      HS-grad      -0.420679
# 32559 -1.216148            Private  0.110930      HS-grad      -0.420679
# 32560  0.983625       Self-emp-inc  0.929812      HS-grad      -0.420679
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male      0.148292     -0.216743       -0.035664   United-States
# 1         Male     -0.145975     -0.216743       -2.222483   United-States
# 2         Male     -0.145975     -0.216743       -0.035664   United-States
# 3         Male     -0.145975     -0.216743       -0.035664   United-States
# 4       Female     -0.145975     -0.216743       -0.035664            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female     -0.145975     -0.216743       -0.197650   United-States
# 32557     Male     -0.145975     -0.216743       -0.035664   United-States
# 32558   Female     -0.145975     -0.216743       -0.035664   United-States
# 32559     Male     -0.145975     -0.216743       -1.655530   United-States
# 32560   Female      1.887635     -0.216743       -0.035664   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32537 rows x 15 columns]

# %%
# To Normalize the numerical columns in the dataset
from sklearn.preprocessing import MinMaxScaler
M_scaler=MinMaxScaler()
numeric_m=df.select_dtypes(include=np.number).columns
df[numeric_m]=M_scaler.fit_transform(df[numeric_m])
df
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male      0.021740           0.0        0.397959   United-States
# 1         Male      0.000000           0.0        0.122449   United-States
# 2         Male      0.000000           0.0        0.397959   United-States
# 3         Male      0.000000           0.0        0.397959   United-States
# 4       Female      0.000000           0.0        0.397959            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female      0.000000           0.0        0.377551   United-States
# 32557     Male      0.000000           0.0        0.397959   United-States
# 32558   Female      0.000000           0.0        0.397959   United-States
# 32559     Male      0.000000           0.0        0.193878   United-States
# 32560   Female      0.150242           0.0        0.397959   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32537 rows x 15 columns]

# %% [markdown]
# ### Discuss the scenarios where each scaling technique is preferred and why.

# %% [markdown]
# **1. StandardScaler**
#
# - StandardScaler transform the data into a fixed range is -3 to +3
# - Works best when data follows a Gaussian (normal) distribution
# - When the data follows a normal distribution or close to it
# - When the variance of features is important
#
# **2. MinMaxScaler**
#
# - Min-Max Scaling transforms the data into a fixed range, typically between 0 and 1
# - Min-Max scaling makes sure that each feature contributes equally to the calculation.
# - For algorithms that rely on distance calculations
# - Best for distance-based models and when data needs to be within a specific range

# %% [markdown]
# ## Encoding techniques

# %%
df1=df.copy()

# %%
cata_data=df1.select_dtypes(include='object').columns
cata_data
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %%
df1['workclass'].nunique()
# Out:
# 9

# %%
df1['education'].nunique()
# Out:
# 16

# %%
df1['marital_status'].nunique()
# Out:
# 7

# %%
df1
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male      0.021740           0.0        0.397959   United-States
# 1         Male      0.000000           0.0        0.122449   United-States
# 2         Male      0.000000           0.0        0.397959   United-States
# 3         Male      0.000000           0.0        0.397959   United-States
# 4       Female      0.000000           0.0        0.397959            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female      0.000000           0.0        0.377551   United-States
# 32557     Male      0.000000           0.0        0.397959   United-States
# 32558   Female      0.000000           0.0        0.397959   United-States
# 32559     Male      0.000000           0.0        0.193878   United-States
# 32560   Female      0.150242           0.0        0.397959   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32537 rows x 15 columns]

# %%
df1['occupation'].nunique()
# Out:
# 15

# %%
df1['relationship'].nunique()
# Out:
# 6

# %%
df1['race'].nunique()
# Out:
# 5

# %%
df1['sex'].nunique()
# Out:
# 2

# %%
df1['native_country'].nunique()
# Out:
# 42

# %%
df1['income'].nunique()
# Out:
# 2

# %%
# Label encoding for categorical variable less than 5 category 
from sklearn.preprocessing import LabelEncoder
L_e=LabelEncoder()
cata_greater5=['workclass','education','marital_status','occupation','relationship','race','native_country']
df1[cata_greater5]=df1[cata_greater5].apply(L_e.fit_transform)
df1
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship  race      sex  capital_gain  \
# 0                   4           1             1     4     Male      0.021740
# 1                   2           4             0     4     Male      0.000000
# 2                   0           6             1     4     Male      0.000000
# 3                   2           6             0     2     Male      0.000000
# 4                   2          10             5     2   Female      0.000000
# ...               ...         ...           ...   ...      ...           ...
# 32556               2          13             5     4   Female      0.000000
# 32557               2           7             0     4     Male      0.000000
# 32558               6           1             4     4   Female      0.000000
# 32559               4           1             3     4     Male      0.000000
# 32560               2           4             5     4   Female      0.150242
#
#        capital_loss  hours_per_week  native_country  income
# 0               0.0        0.397959              39   <=50K
# 1               0.0        0.122449              39   <=50K
# 2               0.0        0.397959              39   <=50K
# 3               0.0        0.397959              39   <=50K
# 4               0.0        0.397959               5   <=50K
# ...             ...             ...             ...     ...
# 32556           0.0        0.377551              39   <=50K
# 32557           0.0        0.397959              39    >50K
# 32558           0.0        0.397959              39   <=50K
# 32559           0.0        0.193878              39   <=50K
# 32560           0.0        0.397959              39    >50K
#
# [32537 rows x 15 columns]

# %%
# apply OneHotEncoding for categorical column less than  5 category
df1_get_dummies=pd.get_dummies(df1[['sex','income']],dtype=int)
df1_get_dummies
# Out:
#        sex_ Female  sex_ Male  income_ <=50K  income_ >50K
# 0                0          1              1             0
# 1                0          1              1             0
# 2                0          1              1             0
# 3                0          1              1             0
# 4                1          0              1             0
# ...            ...        ...            ...           ...
# 32556            1          0              1             0
# 32557            0          1              0             1
# 32558            1          0              1             0
# 32559            0          1              1             0
# 32560            1          0              0             1
#
# [32537 rows x 4 columns]

# %%
# drop the sex variable and concat the dummy variables

df1=pd.concat([df1.drop(columns = ['sex','income']),df1_get_dummies],axis = 1)
df1
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship  race  capital_gain  \
# 0                   4           1             1     4      0.021740
# 1                   2           4             0     4      0.000000
# 2                   0           6             1     4      0.000000
# 3                   2           6             0     2      0.000000
# 4                   2          10             5     2      0.000000
# ...               ...         ...           ...   ...           ...
# 32556               2          13             5     4      0.000000
# 32557               2           7             0     4      0.000000
# 32558               6           1             4     4      0.000000
# 32559               4           1             3     4      0.000000
# 32560               2           4             5     4      0.150242
#
#        capital_loss  hours_per_week  native_country  sex_ Female  sex_ Male  \
# 0               0.0        0.397959              39            0          1
# 1               0.0        0.122449              39            0          1
# 2               0.0        0.397959              39            0          1
# 3               0.0        0.397959              39            0          1
# 4               0.0        0.397959               5            1          0
# ...             ...             ...             ...          ...        ...
# 32556           0.0        0.377551              39            1          0
# 32557           0.0        0.397959              39            0          1
# 32558           0.0        0.397959              39            1          0
# 32559           0.0        0.193878              39            0          1
# 32560           0.0        0.397959              39            1          0
#
#        income_ <=50K  income_ >50K
# 0                  1             0
# 1                  1             0
# 2                  1             0
# 3                  1             0
# 4                  1             0
# ...              ...           ...
# 32556              1             0
# 32557              0             1
# 32558              1             0
# 32559              1             0
# 32560              0             1
#
# [32537 rows x 17 columns]

# %%
df2=df1.rename(columns={'sex_ Female':'Female',
                         'sex_ Male':'Male',
                         'income_ <=50K':'<=50K',
                         'income_ >50K':'>50K'})
df2
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship  race  capital_gain  \
# 0                   4           1             1     4      0.021740
# 1                   2           4             0     4      0.000000
# 2                   0           6             1     4      0.000000
# 3                   2           6             0     2      0.000000
# 4                   2          10             5     2      0.000000
# ...               ...         ...           ...   ...           ...
# 32556               2          13             5     4      0.000000
# 32557               2           7             0     4      0.000000
# 32558               6           1             4     4      0.000000
# 32559               4           1             3     4      0.000000
# 32560               2           4             5     4      0.150242
#
#        capital_loss  hours_per_week  native_country  Female  Male  <=50K  >50K
# 0               0.0        0.397959              39       0     1      1     0
# 1               0.0        0.122449              39       0     1      1     0
# 2               0.0        0.397959              39       0     1      1     0
# 3               0.0        0.397959              39       0     1      1     0
# 4               0.0        0.397959               5       1     0      1     0
# ...             ...             ...             ...     ...   ...    ...   ...
# 32556           0.0        0.377551              39       1     0      1     0
# 32557           0.0        0.397959              39       0     1      0     1
# 32558           0.0        0.397959              39       1     0      1     0
# 32559           0.0        0.193878              39       0     1      1     0
# 32560           0.0        0.397959              39       1     0      0     1
#
# [32537 rows x 17 columns]

# %% [markdown]
# ### Discuss the pros and cons of One-Hot Encoding and Label Encoding.

# %% [markdown]
# **1. Use Label Encoding:**
# - Label Encoding assigns each unique category in a feature to an integer value.
# - For ordinal data where the categories have a clear, meaningful order (e.g., Low, Medium, High).
# - When dealing with high-cardinality features (i.e., features with many unique categories) and when you need to avoid high-dimensionality
# - Label Encoding is simpler and more memory efficient but should be avoided for nominal categories,
#    as it could mislead the model into assuming an ordinal relationship
#
# **2. One-Hot Encoding :**
# - One-Hot Encoding transforms each category into a new binary column (0 or 1). For a categorical feature with n unique values,
#    One-Hot Encoding creates n binary columns.
# - Since each category gets its own binary column, models don’t treat the data as ordinal, avoiding potential misinterpretation.
# - For nominal data where there is no inherent ordering between categories
# - One-Hot Encoding avoids such misinterpretation, making it more suitable for nominal data but can lead to increased dimensionality,
#    which might become computationally expensive for features with many categories.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32537 entries, 0 to 32560
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  float64
#  1   workclass       32537 non-null  int32
#  2   fnlwgt          32537 non-null  float64
#  3   education       32537 non-null  int32
#  4   education_num   32537 non-null  float64
#  5   marital_status  32537 non-null  int32
#  6   occupation      32537 non-null  int32
#  7   relationship    32537 non-null  int32
#  8   race            32537 non-null  int32
#  9   capital_gain    32537 non-null  float64
#  10  capital_loss    32537 non-null  float64
#  11  hours_per_week  32537 non-null  float64
#  12  native_country  32537 non-null  int32
#  13  Female          32537 non-null  int32
#  14  Male            32537 non-null  int32
#  15  <=50K           32537 non-null  int32
#  16  >50K            32537 non-null  int32
# dtypes: float64(6), int32(11)
# memory usage: 3.1 MB

# %% [markdown]
# ## Feature Engineering

# %%
df3=df2.copy()

# %%
df3
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship  race  capital_gain  \
# 0                   4           1             1     4      0.021740
# 1                   2           4             0     4      0.000000
# 2                   0           6             1     4      0.000000
# 3                   2           6             0     2      0.000000
# 4                   2          10             5     2      0.000000
# ...               ...         ...           ...   ...           ...
# 32556               2          13             5     4      0.000000
# 32557               2           7             0     4      0.000000
# 32558               6           1             4     4      0.000000
# 32559               4           1             3     4      0.000000
# 32560               2           4             5     4      0.150242
#
#        capital_loss  hours_per_week  native_country  Female  Male  <=50K  >50K
# 0               0.0        0.397959              39       0     1      1     0
# 1               0.0        0.122449              39       0     1      1     0
# 2               0.0        0.397959              39       0     1      1     0
# 3               0.0        0.397959              39       0     1      1     0
# 4               0.0        0.397959               5       1     0      1     0
# ...             ...             ...             ...     ...   ...    ...   ...
# 32556           0.0        0.377551              39       1     0      1     0
# 32557           0.0        0.397959              39       0     1      0     1
# 32558           0.0        0.397959              39       1     0      1     0
# 32559           0.0        0.193878              39       0     1      1     0
# 32560           0.0        0.397959              39       1     0      0     1
#
# [32537 rows x 17 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df3, features):
    vif = pd.DataFrame()
    vif["Features"] = features
    vif["VIF"] = [variance_inflation_factor(df3[features].values, i) for i in range(df3[features].shape[1])]
    return vif

# Updated list of features
features = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
       'marital_status', 'occupation', 'relationship', 'race', 'capital_gain',
       'capital_loss', 'hours_per_week', 'native_country','Female','Male']

# Calculate VIF for df3
vif_data = calculate_vif(df3, features)
vif_data
# Out:
#           Features        VIF
# 0              age   1.160356
# 1        workclass   1.093985
# 2           fnlwgt   1.012308
# 3        education   1.159195
# 4    education_num   1.218378
# 5   marital_status   1.127315
# 6       occupation   1.091831
# 7     relationship   1.683261
# 8             race   1.038289
# 9     capital_gain   1.028262
# 10    capital_loss   1.015227
# 11  hours_per_week   1.139371
# 12  native_country   1.027527
# 13          Female  30.055136
# 14            Male  57.255718

# %% [markdown]
# ### New Features from High-VIF Variables
#
# **1. Socioeconomic Index**
#
# Formula:socioeconomic_index = workclass * education_num
#
# Rationale: Workclass and education are often related to socioeconomic status.
# Combining them could help capture this relationship while reducing multicollinearity with individual variables.
#
# **2. Cultural Diversity Impact**
# Formula:cultural_diversity = race * native_country
#
# Rationale: Race and native country together might capture the influence of cultural diversity in the dataset.
# This feature could be particularly relevant if these attributes have joint effects on income or other target variables.

# %%
df3['socioeconomic_index'] = df3['workclass'] * df3['education_num']
df3['cultural_diversity'] = df3['race'] * df3['native_country']
df3.drop(columns=['workclass', 'education_num', 'race', 'native_country','Female','Male','<=50K','>50K'], inplace=True)
df3
# Out:
#             age    fnlwgt  education  marital_status  occupation  \
# 0      0.301370  0.044302          9               4           1
# 1      0.452055  0.048238          9               2           4
# 2      0.287671  0.138113         11               0           6
# 3      0.493151  0.151068          1               2           6
# 4      0.150685  0.221488          9               2          10
# ...         ...       ...        ...             ...         ...
# 32556  0.136986  0.166404          7               2          13
# 32557  0.315068  0.096500         11               2           7
# 32558  0.561644  0.094827         11               6           1
# 32559  0.068493  0.128499         11               4           1
# 32560  0.479452  0.187203         11               2           4
#
#        relationship  capital_gain  capital_loss  hours_per_week  \
# 0                 1      0.021740           0.0        0.397959
# 1                 0      0.000000           0.0        0.122449
# 2                 1      0.000000           0.0        0.397959
# 3                 0      0.000000           0.0        0.397959
# 4                 5      0.000000           0.0        0.397959
# ...             ...           ...           ...             ...
# 32556             5      0.000000           0.0        0.377551
# 32557             0      0.000000           0.0        0.397959
# 32558             4      0.000000           0.0        0.397959
# 32559             3      0.000000           0.0        0.193878
# 32560             5      0.150242           0.0        0.397959
#
#        socioeconomic_index  cultural_diversity
# 0                 5.600000                 156
# 1                 4.800000                 156
# 2                 2.133333                 156
# 3                 1.600000                  78
# 4                 3.200000                  10
# ...                    ...                 ...
# 32556             2.933333                 156
# 32557             2.133333                 156
# 32558             2.133333                 156
# 32559             2.133333                 156
# 32560             2.666667                 156
#
# [32537 rows x 11 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df3, features):
    vif = pd.DataFrame()
    vif["Features"] = features
    vif["VIF"] = [variance_inflation_factor(df3[features].values, i) for i in range(df3[features].shape[1])]
    return vif

# Updated list of features
features = ['age', 'fnlwgt', 'education','marital_status', 'occupation', 'relationship', 'capital_gain',
       'capital_loss', 'hours_per_week','socioeconomic_index','cultural_diversity']

# Calculate VIF for df3
vif_data = calculate_vif(df3, features)
vif_data
# Out:
#                Features       VIF
# 0                   age  3.409793
# 1                fnlwgt  3.513590
# 2             education  7.643877
# 3        marital_status  3.736791
# 4            occupation  3.536408
# 5          relationship  1.876173
# 6          capital_gain  1.041663
# 7          capital_loss  1.058727
# 8        hours_per_week  9.394661
# 9   socioeconomic_index  5.789489
# 10   cultural_diversity  8.722851

# %%
#log transformation
# Apply log1p transformation to reduce skewness for highly skewed features
df3['capital_gain_log'] = np.log1p(df3['capital_gain'])
df3['capital_loss_log'] = np.log1p(df3['capital_loss'])

# Calculate skewness for transformed features
transformed_skewness = df3[['capital_gain_log', 'capital_loss_log']].skew()

# Display the results
print("Skewness after transformation:")
print(transformed_skewness)
# Out:
# Skewness after transformation:
# capital_gain_log    10.667468
# capital_loss_log     4.493062
# dtype: float64

# %%
df3.drop(columns=['capital_gain','capital_loss'], inplace = True)
df3
# Out:
#             age    fnlwgt  education  marital_status  occupation  \
# 0      0.301370  0.044302          9               4           1
# 1      0.452055  0.048238          9               2           4
# 2      0.287671  0.138113         11               0           6
# 3      0.493151  0.151068          1               2           6
# 4      0.150685  0.221488          9               2          10
# ...         ...       ...        ...             ...         ...
# 32556  0.136986  0.166404          7               2          13
# 32557  0.315068  0.096500         11               2           7
# 32558  0.561644  0.094827         11               6           1
# 32559  0.068493  0.128499         11               4           1
# 32560  0.479452  0.187203         11               2           4
#
#        relationship  hours_per_week  socioeconomic_index  cultural_diversity  \
# 0                 1        0.397959             5.600000                 156
# 1                 0        0.122449             4.800000                 156
# 2                 1        0.397959             2.133333                 156
# 3                 0        0.397959             1.600000                  78
# 4                 5        0.397959             3.200000                  10
# ...             ...             ...                  ...                 ...
# 32556             5        0.377551             2.933333                 156
# 32557             0        0.397959             2.133333                 156
# 32558             4        0.397959             2.133333                 156
# 32559             3        0.193878             2.133333                 156
# 32560             5        0.397959             2.666667                 156
#
#        capital_gain_log  capital_loss_log
# 0              0.021507               0.0
# 1              0.000000               0.0
# 2              0.000000               0.0
# 3              0.000000               0.0
# 4              0.000000               0.0
# ...                 ...               ...
# 32556          0.000000               0.0
# 32557          0.000000               0.0
# 32558          0.000000               0.0
# 32559          0.000000               0.0
# 32560          0.139972               0.0
#
# [32537 rows x 11 columns]

# %% [markdown]
# ## Feature selection

# %%
from sklearn.ensemble import IsolationForest
clf=IsolationForest(random_state=10,contamination=0.01)
clf.fit(df3)
# Out:
# IsolationForest(contamination=0.01, random_state=10)

# %%
y_pred=clf.predict(df3)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
df3.loc[y_pred==-1]
# Out:
#             age    fnlwgt  education  marital_status  occupation  \
# 52     0.410959  0.026861         14               2          10
# 93     0.178082  0.071625         11               2          12
# 106    0.000000  0.198712          0               4           0
# 157    0.739726  0.327310         15               5          12
# 226    0.589041  0.008102          0               0           0
# ...         ...       ...        ...             ...         ...
# 32090  0.671233  0.070098          9               2           4
# 32238  0.410959  0.191948         14               2           4
# 32341  0.780822  0.126901          9               6           3
# 32370  0.493151  0.085072         14               4          10
# 32525  0.876712  0.073480          8               0           0
#
#        relationship  hours_per_week  socioeconomic_index  cultural_diversity  \
# 52                5        0.602041             3.733333                  64
# 93                5        0.346939             2.133333                   0
# 106               3        0.316327             0.000000                 156
# 157               4        0.010204             3.600000                  78
# 226               1        0.091837             0.000000                   0
# ...             ...             ...                  ...                 ...
# 32090             0        0.551020             3.200000                   0
# 32238             0        0.397959             3.733333                 156
# 32341             1        0.071429             4.800000                  44
# 32370             1        0.397959             5.600000                  30
# 32525             4        0.000000             0.000000                   0
#
#        capital_gain_log  capital_loss_log
# 52             0.000000          0.362306
# 93             0.000000          0.308301
# 106            0.293381          0.000000
# 157            0.000000          0.348469
# 226            0.000000          0.000000
# ...                 ...               ...
# 32090          0.693147          0.000000
# 32238          0.693147          0.000000
# 32341          0.146963          0.000000
# 32370          0.245518          0.000000
# 32525          0.000000          0.000000
#
# [326 rows x 11 columns]

# %%
# removing outliers
# Get the indices of the outliers
outlier_indices = df3.loc[y_pred == -1].index

# Remove the outliers from the DataFrame
df3 = df3.drop(outlier_indices)
df3.shape
# Out:
# (32211, 11)

# %%
correlation_matrix=df3.corr()
correlation_matrix
# Out:
#                           age    fnlwgt  education  marital_status  \
# age                  1.000000 -0.077746  -0.006734       -0.285416
# fnlwgt              -0.077746  1.000000  -0.029249        0.029109
# education           -0.006734 -0.029249   1.000000       -0.034781
# marital_status      -0.285416  0.029109  -0.034781        1.000000
# occupation          -0.017593  0.000320  -0.023463       -0.006111
# relationship        -0.272455  0.008122  -0.009498        0.187093
# hours_per_week       0.078875 -0.020551   0.055301       -0.186627
# socioeconomic_index  0.030297 -0.038825   0.209797       -0.077686
# cultural_diversity   0.028778 -0.054956   0.053152       -0.065547
# capital_gain_log     0.081634 -0.012614   0.021511       -0.051990
# capital_loss_log     0.051516 -0.011114   0.019296       -0.039700
#
#                      occupation  relationship  hours_per_week  \
# age                   -0.017593     -0.272455        0.078875
# fnlwgt                 0.000320      0.008122       -0.020551
# education             -0.023463     -0.009498        0.055301
# marital_status        -0.006111      0.187093       -0.186627
# occupation             1.000000     -0.074996        0.074058
# relationship          -0.074996      1.000000       -0.249697
# hours_per_week         0.074058     -0.249697        1.000000
# socioeconomic_index    0.234927     -0.122439        0.179948
# cultural_diversity    -0.000221     -0.089008        0.030882
# capital_gain_log       0.013052     -0.080918        0.075357
# capital_loss_log       0.018500     -0.067560        0.056153
#
#                      socioeconomic_index  cultural_diversity  \
# age                             0.030297            0.028778
# fnlwgt                         -0.038825           -0.054956
# education                       0.209797            0.053152
# marital_status                 -0.077686           -0.065547
# occupation                      0.234927           -0.000221
# relationship                   -0.122439           -0.089008
# hours_per_week                  0.179948            0.030882
# socioeconomic_index             1.000000            0.063287
# cultural_diversity              0.063287            1.000000
# capital_gain_log                0.088169            0.035732
# capital_loss_log                0.054084            0.032612
#
#                      capital_gain_log  capital_loss_log
# age                          0.081634          0.051516
# fnlwgt                      -0.012614         -0.011114
# education                    0.021511          0.019296
# marital_status              -0.051990         -0.039700
# occupation                   0.013052          0.018500
# relationship                -0.080918         -0.067560
# hours_per_week               0.075357          0.056153
# socioeconomic_index          0.088169          0.054084
# cultural_diversity           0.035732          0.032612
# capital_gain_log             1.000000         -0.037646
# capital_loss_log            -0.037646          1.000000

# %%
# To reset the index
df3.reset_index(drop=True,inplace=True)
df3
# Out:
#             age    fnlwgt  education  marital_status  occupation  \
# 0      0.301370  0.044302          9               4           1
# 1      0.452055  0.048238          9               2           4
# 2      0.287671  0.138113         11               0           6
# 3      0.493151  0.151068          1               2           6
# 4      0.150685  0.221488          9               2          10
# ...         ...       ...        ...             ...         ...
# 32206  0.136986  0.166404          7               2          13
# 32207  0.315068  0.096500         11               2           7
# 32208  0.561644  0.094827         11               6           1
# 32209  0.068493  0.128499         11               4           1
# 32210  0.479452  0.187203         11               2           4
#
#        relationship  hours_per_week  socioeconomic_index  cultural_diversity  \
# 0                 1        0.397959             5.600000                 156
# 1                 0        0.122449             4.800000                 156
# 2                 1        0.397959             2.133333                 156
# 3                 0        0.397959             1.600000                  78
# 4                 5        0.397959             3.200000                  10
# ...             ...             ...                  ...                 ...
# 32206             5        0.377551             2.933333                 156
# 32207             0        0.397959             2.133333                 156
# 32208             4        0.397959             2.133333                 156
# 32209             3        0.193878             2.133333                 156
# 32210             5        0.397959             2.666667                 156
#
#        capital_gain_log  capital_loss_log
# 0              0.021507               0.0
# 1              0.000000               0.0
# 2              0.000000               0.0
# 3              0.000000               0.0
# 4              0.000000               0.0
# ...                 ...               ...
# 32206          0.000000               0.0
# 32207          0.000000               0.0
# 32208          0.000000               0.0
# 32209          0.000000               0.0
# 32210          0.139972               0.0
#
# [32211 rows x 11 columns]

# %%
# correlation heatmap
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,7))
cor = df.corr(numeric_only=True)
sns.heatmap(cor, annot=True, cmap='rainbow',fmt='.2f',linecolor='blue',linewidth=1.5,cbar=True)
plt.show()

# %%
# !pip install ppscore
# Out:
# Collecting ppscore
#   Using cached ppscore-1.3.0-py2.py3-none-any.whl
# Collecting pandas<2.0.0,>=1.0.0 (from ppscore)
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in c:\users\rohith r\anaconda3\lib\site-packages (from ppscore) (1.5.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.0.0->ppscore) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rohith r\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rohith r\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rohith r\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\rohith r\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->ppscore) (1.16.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml): started
#   Building wheel for pandas (pyproject.toml): still running...
#   Building wheel for pandas (pyproject.toml): still running...
#   Building wheel for pandas (pyproject.toml): still running...
#   Building wheel for pandas (pyproject.toml): finished with status 'done'
#   Created wheel for pandas: filename=pandas-1.5.3-cp312-cp312-win_amd64.whl size=9863168 sha256=d42f713c01025e78bafbf7a7afcc6174a67e4211c8e45b4806bde431638ed94a
#   Stored in directory: c:\users\rohith r\appdata\local\pip\cache\wheels\fb\83\18\8e7307aa1185c5498c5490e4d9c8a1732d9f1056e86c3491c6
# Successfully built pandas
# Installing collected packages: pandas, ppscore
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed pandas-1.5.3 ppscore-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-expr 1.1.13 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\rohith r\anaconda3\lib\site-packages (1.5.3)
# Collecting pandas
#   Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohith r\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rohith r\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 8.3 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.0 MB 3.1 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.0 MB 4.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 4.3 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 4.2 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/11.0 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/11.0 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.0 MB 4.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.0 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# Successfully installed pandas-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ppscore 1.3.0 requires pandas<2.0.0,>=1.0.0, but you have pandas 2.3.0 which is incompatible.

# %%
# since the ppscore is not compitable with higher version of pandas 
#If we downgrade the pandas then it affects the other packages of different assignments so i am just presenting the syntax of it
#PPS (Predictive Power Score)
import ppscore as pps

# Calculate the PPS between all pairs of columns, with 'income' as the target variable
pps_matrix = pps.predictors(df, y="income")  # Specify the target column

# Display the PPS matrix
pps_matrix

# %% [markdown]
# ### Comparison Summary:
#
# - 1. Correlation matrix reveals linear relationships between numerical features,
# while PPS assesses the predictive power of features for the target variable.
# - 2. Correlation might show strong relationships that are not predictive, whereas PPS focuses on how well a feature predicts the target.
# - 3.  Correlation coefficients are symmetrical, but PPS scores are directional,
# showing the predictive power of feature X for feature Y, but not the reverse.
# - 4. PPS provides a more comprehensive understanding of feature importance for predictive modeling,
# while the correlation matrix is mainly for numerical features.
# - 5. Comparing both methods helps identify features important for prediction,
# while also considering possible collinearity issues from the correlation matrix.
